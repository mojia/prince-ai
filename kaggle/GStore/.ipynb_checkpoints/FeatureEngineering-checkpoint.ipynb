# %%
# reference: https://www.kaggle.com/sudalairajkumar/simple-exploration-baseline-ga-customer-revenue

import pandas as pd
import json


dir='/Users/xinwang/ai/dataset/kaggle/GStore/'

def load_df(filename, nrows=None):
    JSON_COLUMNS = ['device','geoNetwork','totals','trafficSource']
    
    df = pd.read_csv(dir+filename, converters = {column: json.loads for column in JSON_COLUMNS},
                    dtype={'fullVisitorId':'str'},
                    nrows=nrows)
    for column in JSON_COLUMNS:
        column_as_df = pd.io.json.json_normalize(df[column])
        column_as_df.columns = [f"{column}.{subcolumn}" for subcolumn in column_as_df.columns]
        
        df = df.drop(column, axis=1).merge(column_as_df, right_index=True, left_index=True)
        print('load col', column)
        
    print(f"Loaded" ,filename," shape", df.shape, df.columns)
    
    return df

train_df = load_df('train.csv')
# test_df = load_df('test.csv')
# Out:
# load col device
# load col geoNetwork
# load col totals
# load col trafficSource
# Loaded train.csv  shape (903653, 55) Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'device.browser', 'device.browserSize', 'device.browserVersion',
#        'device.deviceCategory', 'device.flashVersion', 'device.isMobile',
#        'device.language', 'device.mobileDeviceBranding',
#        'device.mobileDeviceInfo', 'device.mobileDeviceMarketingName',
#        'device.mobileDeviceModel', 'device.mobileInputSelector',
#        'device.operatingSystem', 'device.operatingSystemVersion',
#        'device.screenColors', 'device.screenResolution', 'geoNetwork.city',
#        'geoNetwork.cityId', 'geoNetwork.continent', 'geoNetwork.country',
#        'geoNetwork.latitude', 'geoNetwork.longitude', 'geoNetwork.metro',
#        'geoNetwork.networkDomain', 'geoNetwork.networkLocation',
#        'geoNetwork.region', 'geoNetwork.subContinent', 'totals.bounces',
#        'totals.hits', 'totals.newVisits', 'totals.pageviews',
#        'totals.transactionRevenue', 'totals.visits', 'trafficSource.adContent',
#        'trafficSource.adwordsClickInfo.adNetworkType',
#        'trafficSource.adwordsClickInfo.criteriaParameters',
#        'trafficSource.adwordsClickInfo.gclId',
#        'trafficSource.adwordsClickInfo.isVideoAd',
#        'trafficSource.adwordsClickInfo.page',
#        'trafficSource.adwordsClickInfo.slot', 'trafficSource.campaign',
#        'trafficSource.campaignCode', 'trafficSource.isTrueDirect',
#        'trafficSource.keyword', 'trafficSource.medium',
#        'trafficSource.referralPath', 'trafficSource.source'],
#       dtype='object')

# %%
train_df.T.head(100)
# Out:
#                                                                            0       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 1131660440785968503
# sessionId                                          1131660440785968503_1472830385
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472830385
# visitNumber                                                                     1
# visitStartTime                                                         1472830385
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                                             Izmir
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                         Asia
# geoNetwork.country                                                         Turkey
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                                        (not set)
# geoNetwork.networkDomain                                             ttnet.com.tr
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                                           Izmir
# geoNetwork.subContinent                                              Western Asia
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                           1       \
# channelGrouping                                                   Organic Search
# date                                                                    20160902
# fullVisitorId                                                 377306020877927890
# sessionId                                          377306020877927890_1472880147
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1472880147
# visitNumber                                                                    1
# visitStartTime                                                        1472880147
# device.browser                                                           Firefox
# device.browserSize                                 not available in demo dataset
# device.browserVersion                              not available in demo dataset
# device.deviceCategory                                                    desktop
# device.flashVersion                                not available in demo dataset
# device.isMobile                                                            False
# device.language                                    not available in demo dataset
# device.mobileDeviceBranding                        not available in demo dataset
# device.mobileDeviceInfo                            not available in demo dataset
# device.mobileDeviceMarketingName                   not available in demo dataset
# device.mobileDeviceModel                           not available in demo dataset
# device.mobileInputSelector                         not available in demo dataset
# device.operatingSystem                                                 Macintosh
# device.operatingSystemVersion                      not available in demo dataset
# device.screenColors                                not available in demo dataset
# device.screenResolution                            not available in demo dataset
# geoNetwork.city                                    not available in demo dataset
# geoNetwork.cityId                                  not available in demo dataset
# geoNetwork.continent                                                     Oceania
# geoNetwork.country                                                     Australia
# geoNetwork.latitude                                not available in demo dataset
# geoNetwork.longitude                               not available in demo dataset
# geoNetwork.metro                                   not available in demo dataset
# geoNetwork.networkDomain                                             dodo.net.au
# geoNetwork.networkLocation                         not available in demo dataset
# geoNetwork.region                                  not available in demo dataset
# geoNetwork.subContinent                                              Australasia
# totals.bounces                                                                 1
# totals.hits                                                                    1
# totals.newVisits                                                               1
# totals.pageviews                                                               1
# totals.transactionRevenue                                                    NaN
# totals.visits                                                                  1
# trafficSource.adContent                                                      NaN
# trafficSource.adwordsClickInfo.adNetworkType                                 NaN
# trafficSource.adwordsClickInfo.criteriaParameters  not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                         NaN
# trafficSource.adwordsClickInfo.isVideoAd                                     NaN
# trafficSource.adwordsClickInfo.page                                          NaN
# trafficSource.adwordsClickInfo.slot                                          NaN
# trafficSource.campaign                                                 (not set)
# trafficSource.campaignCode                                                   NaN
# trafficSource.isTrueDirect                                                   NaN
# trafficSource.keyword                                             (not provided)
# trafficSource.medium                                                     organic
# trafficSource.referralPath                                                   NaN
# trafficSource.source                                                      google
#
#                                                                            2       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 3895546263509774583
# sessionId                                          3895546263509774583_1472865386
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472865386
# visitNumber                                                                     1
# visitStartTime                                                         1472865386
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                                            Madrid
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                       Europe
# geoNetwork.country                                                          Spain
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                                        (not set)
# geoNetwork.networkDomain                                          unknown.unknown
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                             Community of Madrid
# geoNetwork.subContinent                                           Southern Europe
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                            3       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 4763447161404445595
# sessionId                                          4763447161404445595_1472881213
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472881213
# visitNumber                                                                     1
# visitStartTime                                                         1472881213
# device.browser                                                         UC Browser
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                      Linux
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                         Asia
# geoNetwork.country                                                      Indonesia
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                          unknown.unknown
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                            Southeast Asia
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                             google + online
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                           4       \
# channelGrouping                                                   Organic Search
# date                                                                    20160902
# fullVisitorId                                                  27294437909732085
# sessionId                                           27294437909732085_1472822600
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1472822600
# visitNumber                                                                    2
# visitStartTime                                                        1472822600
# device.browser                                                            Chrome
# device.browserSize                                 not available in demo dataset
# device.browserVersion                              not available in demo dataset
# device.deviceCategory                                                     mobile
# device.flashVersion                                not available in demo dataset
# device.isMobile                                                             True
# device.language                                    not available in demo dataset
# device.mobileDeviceBranding                        not available in demo dataset
# device.mobileDeviceInfo                            not available in demo dataset
# device.mobileDeviceMarketingName                   not available in demo dataset
# device.mobileDeviceModel                           not available in demo dataset
# device.mobileInputSelector                         not available in demo dataset
# device.operatingSystem                                                   Android
# device.operatingSystemVersion                      not available in demo dataset
# device.screenColors                                not available in demo dataset
# device.screenResolution                            not available in demo dataset
# geoNetwork.city                                    not available in demo dataset
# geoNetwork.cityId                                  not available in demo dataset
# geoNetwork.continent                                                      Europe
# geoNetwork.country                                                United Kingdom
# geoNetwork.latitude                                not available in demo dataset
# geoNetwork.longitude                               not available in demo dataset
# geoNetwork.metro                                   not available in demo dataset
# geoNetwork.networkDomain                                         unknown.unknown
# geoNetwork.networkLocation                         not available in demo dataset
# geoNetwork.region                                  not available in demo dataset
# geoNetwork.subContinent                                          Northern Europe
# totals.bounces                                                                 1
# totals.hits                                                                    1
# totals.newVisits                                                             NaN
# totals.pageviews                                                               1
# totals.transactionRevenue                                                    NaN
# totals.visits                                                                  1
# trafficSource.adContent                                                      NaN
# trafficSource.adwordsClickInfo.adNetworkType                                 NaN
# trafficSource.adwordsClickInfo.criteriaParameters  not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                         NaN
# trafficSource.adwordsClickInfo.isVideoAd                                     NaN
# trafficSource.adwordsClickInfo.page                                          NaN
# trafficSource.adwordsClickInfo.slot                                          NaN
# trafficSource.campaign                                                 (not set)
# trafficSource.campaignCode                                                   NaN
# trafficSource.isTrueDirect                                                  True
# trafficSource.keyword                                             (not provided)
# trafficSource.medium                                                     organic
# trafficSource.referralPath                                                   NaN
# trafficSource.source                                                      google
#
#                                                                            5       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 2938943183656635653
# sessionId                                          2938943183656635653_1472807194
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472807194
# visitNumber                                                                     1
# visitStartTime                                                         1472807194
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                       Europe
# geoNetwork.country                                                          Italy
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                            fastwebnet.it
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                           Southern Europe
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                            6       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 1905672039242460897
# sessionId                                          1905672039242460897_1472817241
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472817241
# visitNumber                                                                     1
# visitStartTime                                                         1472817241
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                         Asia
# geoNetwork.country                                                       Pakistan
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                          unknown.unknown
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                             Southern Asia
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                           7       \
# channelGrouping                                                   Organic Search
# date                                                                    20160902
# fullVisitorId                                                 537222803633850821
# sessionId                                          537222803633850821_1472812602
# socialEngagementType                                        Not Socially Engaged
# visitId                                                               1472812602
# visitNumber                                                                    1
# visitStartTime                                                        1472812602
# device.browser                                                            Chrome
# device.browserSize                                 not available in demo dataset
# device.browserVersion                              not available in demo dataset
# device.deviceCategory                                                    desktop
# device.flashVersion                                not available in demo dataset
# device.isMobile                                                            False
# device.language                                    not available in demo dataset
# device.mobileDeviceBranding                        not available in demo dataset
# device.mobileDeviceInfo                            not available in demo dataset
# device.mobileDeviceMarketingName                   not available in demo dataset
# device.mobileDeviceModel                           not available in demo dataset
# device.mobileInputSelector                         not available in demo dataset
# device.operatingSystem                                                   Windows
# device.operatingSystemVersion                      not available in demo dataset
# device.screenColors                                not available in demo dataset
# device.screenResolution                            not available in demo dataset
# geoNetwork.city                                                         Brisbane
# geoNetwork.cityId                                  not available in demo dataset
# geoNetwork.continent                                                     Oceania
# geoNetwork.country                                                     Australia
# geoNetwork.latitude                                not available in demo dataset
# geoNetwork.longitude                               not available in demo dataset
# geoNetwork.metro                                                       (not set)
# geoNetwork.networkDomain                                          bigpond.net.au
# geoNetwork.networkLocation                         not available in demo dataset
# geoNetwork.region                                                     Queensland
# geoNetwork.subContinent                                              Australasia
# totals.bounces                                                                 1
# totals.hits                                                                    1
# totals.newVisits                                                               1
# totals.pageviews                                                               1
# totals.transactionRevenue                                                    NaN
# totals.visits                                                                  1
# trafficSource.adContent                                                      NaN
# trafficSource.adwordsClickInfo.adNetworkType                                 NaN
# trafficSource.adwordsClickInfo.criteriaParameters  not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                         NaN
# trafficSource.adwordsClickInfo.isVideoAd                                     NaN
# trafficSource.adwordsClickInfo.page                                          NaN
# trafficSource.adwordsClickInfo.slot                                          NaN
# trafficSource.campaign                                                 (not set)
# trafficSource.campaignCode                                                   NaN
# trafficSource.isTrueDirect                                                   NaN
# trafficSource.keyword                                             (not provided)
# trafficSource.medium                                                     organic
# trafficSource.referralPath                                                   NaN
# trafficSource.source                                                      google
#
#                                                                            8       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 4445454811831400414
# sessionId                                          4445454811831400414_1472805784
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472805784
# visitNumber                                                                     1
# visitStartTime                                                         1472805784
# device.browser                                                  Internet Explorer
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                       Europe
# geoNetwork.country                                                        Austria
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                                  spar.at
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                            Western Europe
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                            9       \
# channelGrouping                                                    Organic Search
# date                                                                     20160902
# fullVisitorId                                                 9499785259412240342
# sessionId                                          9499785259412240342_1472812272
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1472812272
# visitNumber                                                                     1
# visitStartTime                                                         1472812272
# device.browser                                                            Firefox
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                       Europe
# geoNetwork.country                                                    Netherlands
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                                chello.nl
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                            Western Europe
# totals.bounces                                                                  1
# totals.hits                                                                     1
# totals.newVisits                                                                1
# totals.pageviews                                                                1
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                              (not provided)
# trafficSource.medium                                                      organic
# trafficSource.referralPath                                                    NaN
# trafficSource.source                                                       google
#
#                                                                 ...                \
# channelGrouping                                                 ...
# date                                                            ...
# fullVisitorId                                                   ...
# sessionId                                                       ...
# socialEngagementType                                            ...
# ...
# totals.bounces                                                                NaN
# totals.hits                                                                    18
# totals.newVisits                                                                1
# totals.pageviews                                                               13
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                                         NaN
# trafficSource.medium                                                     referral
# trafficSource.referralPath                                             /yt/about/
# trafficSource.source                                                  youtube.com
#
#                                                                            903650  \
# channelGrouping                                                            Social
# date                                                                     20170104
# fullVisitorId                                                 5744576632396406899
# sessionId                                          5744576632396406899_1483526434
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1483526434
# visitNumber                                                                     1
# visitStartTime                                                         1483526434
# device.browser                                                    Android Webview
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                      mobile
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                              True
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Android
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                                             Seoul
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                         Asia
# geoNetwork.country                                                    South Korea
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                                        (not set)
# geoNetwork.networkDomain                                          unknown.unknown
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                                           Seoul
# geoNetwork.subContinent                                              Eastern Asia
# totals.bounces                                                                NaN
# totals.hits                                                                    24
# totals.newVisits                                                                1
# totals.pageviews                                                               21
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                                         NaN
# trafficSource.medium                                                     referral
# trafficSource.referralPath                                          /yt/about/ko/
# trafficSource.source                                                  youtube.com
#
#                                                                            903651  \
# channelGrouping                                                            Social
# date                                                                     20170104
# fullVisitorId                                                 2709355455991750775
# sessionId                                          2709355455991750775_1483592857
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1483592857
# visitNumber                                                                     1
# visitStartTime                                                         1483592864
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                     desktop
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                             False
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Windows
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                         Asia
# geoNetwork.country                                                      Indonesia
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                          unknown.unknown
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                            Southeast Asia
# totals.bounces                                                                NaN
# totals.hits                                                                    24
# totals.newVisits                                                                1
# totals.pageviews                                                               22
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                                         NaN
# trafficSource.medium                                                     referral
# trafficSource.referralPath                                                 /l.php
# trafficSource.source                                                 facebook.com
#
#                                                                            903652
# channelGrouping                                                            Social
# date                                                                     20170104
# fullVisitorId                                                 0814900163617805053
# sessionId                                          0814900163617805053_1483574474
# socialEngagementType                                         Not Socially Engaged
# visitId                                                                1483574474
# visitNumber                                                                     1
# visitStartTime                                                         1483574474
# device.browser                                                             Chrome
# device.browserSize                                  not available in demo dataset
# device.browserVersion                               not available in demo dataset
# device.deviceCategory                                                      mobile
# device.flashVersion                                 not available in demo dataset
# device.isMobile                                                              True
# device.language                                     not available in demo dataset
# device.mobileDeviceBranding                         not available in demo dataset
# device.mobileDeviceInfo                             not available in demo dataset
# device.mobileDeviceMarketingName                    not available in demo dataset
# device.mobileDeviceModel                            not available in demo dataset
# device.mobileInputSelector                          not available in demo dataset
# device.operatingSystem                                                    Android
# device.operatingSystemVersion                       not available in demo dataset
# device.screenColors                                 not available in demo dataset
# device.screenResolution                             not available in demo dataset
# geoNetwork.city                                     not available in demo dataset
# geoNetwork.cityId                                   not available in demo dataset
# geoNetwork.continent                                                     Americas
# geoNetwork.country                                                         Mexico
# geoNetwork.latitude                                 not available in demo dataset
# geoNetwork.longitude                                not available in demo dataset
# geoNetwork.metro                                    not available in demo dataset
# geoNetwork.networkDomain                                        cybercable.net.mx
# geoNetwork.networkLocation                          not available in demo dataset
# geoNetwork.region                                   not available in demo dataset
# geoNetwork.subContinent                                           Central America
# totals.bounces                                                                NaN
# totals.hits                                                                    31
# totals.newVisits                                                                1
# totals.pageviews                                                               31
# totals.transactionRevenue                                                     NaN
# totals.visits                                                                   1
# trafficSource.adContent                                                       NaN
# trafficSource.adwordsClickInfo.adNetworkType                                  NaN
# trafficSource.adwordsClickInfo.criteriaParameters   not available in demo dataset
# trafficSource.adwordsClickInfo.gclId                                          NaN
# trafficSource.adwordsClickInfo.isVideoAd                                      NaN
# trafficSource.adwordsClickInfo.page                                           NaN
# trafficSource.adwordsClickInfo.slot                                           NaN
# trafficSource.campaign                                                  (not set)
# trafficSource.campaignCode                                                    NaN
# trafficSource.isTrueDirect                                                    NaN
# trafficSource.keyword                                                         NaN
# trafficSource.medium                                                     referral
# trafficSource.referralPath                                      /yt/about/es-419/
# trafficSource.source                                                  youtube.com
#
# [55 rows x 903653 columns]

# %%
# 'fullVisitorId',
train_df[['device.browser','totals.transactionRevenue']].groupby(
    by=['device.browser'], as_index=False).agg('count').sort_values('totals.transactionRevenue', ascending=False)
# Out:
#                                  device.browser  totals.transactionRevenue
# 11                                       Chrome                      10353
# 40                                       Safari                        780
# 16                                      Firefox                        191
# 20                            Internet Explorer                        109
# 15                                         Edge                         58
# 41                              Safari (in-app)                         12
# 6                               Android Webview                          6
# 36                                        Opera                          5
# 3                                   Amazon Silk                          1
# 34                                Nokia Browser                          0
# 35                                   NokiaE52-1                          0
# 42                                    SeaMonkey                          0
# 37                                   Opera Mini                          0
# 38                                       Puffin                          0
# 33                             Nintendo Browser                          0
# 39                                       Reddit                          0
# 32                                     Nichrome                          0
# 0                                     (not set)                          0
# 30                                      Mozilla                          0
# 43                                       Seznam                          0
# 44                                    TCL P500M                          0
# 45                                  ThumbSniper                          0
# 46                                   UC Browser                          0
# 47                                   User Agent                          0
# 48                                           YE                          0
# 49                                    YaBrowser                          0
# 50  [Use default User-agent string] LIVRENPOCHE                          0
# 51                                        no-ua                          0
# 52                          osee2unifiedRelease                          0
# 31                     Mozilla Compatible Agent                          0
# 27                                   MQQBrowser                          0
# 29                                      Maxthon                          0
# 14                                       DoCoMo                          0
# 2                                           ADM                          0
# 4                               Android Browser                          0
# 5                               Android Runtime                          0
# 7                               Apple-iPhone7C2                          0
# 8                                    BlackBerry                          0
# 9                                     CSM Click                          0
# 10                              Changa 99695759                          0
# 12                                      Coc Coc                          0
# 13                                   DASH_JR_3G                          0
# 17                                   HTC802t_TD                          0
# 28                                     MRCHROME                          0
# 18                            Hisense M20-M_LTE                          0
# 19                         IE with Chrome Frame                          0
# 21                                         Iron                          0
# 22                                    Konqueror                          0
# 23                               LYF_LS_4002_11                          0
# 24                               LYF_LS_4002_12                          0
# 25                                    Lunascape                          0
# 26                                           M5                          0
# 1                                             0                          0
# 53                   subjectAgent: NoticiasBoom                          0

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
train_df_copy = scaler.fit_transform(train_df)
train_df_copy.head()

# %%
def merge_some_similar_browser(x):
    x = x.replace("Safari (in-app)","Safari")
    x = x.replace("Apple-iPhone7C2","Safari")
    x = x.replace("Android Browser","Android Webview")
    x = x.replace("Opera Mini","Opera")
    x = x.replace("Mozilla Compatible Agent","Firefox")
    x = x.replace("Mozilla","Firefox")
    
    x = x.replace("MRCHROME","Chrome")
    
    return x
    
train_df['device.browser'] = train_df['device.browser'].apply(merge_some_similar_browser)

# %%
def merge_some_similar_operatingSystem(x):
    x = x.replace("Windows Phone","Windows")
    x = x.replace("Samsung","Android")
    
    return x
    
train_df['device.operatingSystem'] = train_df['device.operatingSystem'].apply(merge_some_similar_operatingSystem)

# %%
import re

networkDomain_array = train_df['geoNetwork.networkDomain'].unique()
networkDomain = np.array(networkDomain_array)
print('networkDomain size', len(networkDomain))

suffixs = set()
for i in networkDomain:
    suffix = i.split('.')[-1]

    suffix = suffix.replace("\\032","")

    if re.search('[a-zA-Z]', i):
        suffixs.add(suffix)
# Out:
# networkDomain size 28063
# 168.234
# 253.208
# 67.177
# 18.178
# 29.25
# 87.63
# 203.65
# 130.2
# 216.65
# 305 {'rs', 'tj', 'years', 'in-arpa', 'za', 'website', 'cool', 'to', 'vg', 'gl', 'bs', 'xyz', 'uy', 'cy', 'tld', 'unknown', 'biz', 'life', 'chicago', 'invalid', 'available', 'server', 'xn--p1ai', 'lcl', 'uz', 'mil', 'nf', 'af', 'ca', 'ad', 'spoofed', 'cyclons', 'ws', 'systems', 'ru', 'kz', 'ninja', 'userbizslimit-16258', 'bn', 'bm', 'cz', 'mm', 'ir', 'br', 're', 'uk', 'be', 'at', 'kq', 'vi', 'py', 'lb', 'cr', 'arqiva', 'bd', 'ppp', 'nasdaq-admin', '28', 'mk', 'al', 'it', 'rw', 'pl', 'aero', 'de', 'aw', 'bw', 'deloitte', 'travel', 'yu', 'cc', 'pk', 'chinamobile', 'vc', 'arp', 'vn', 'nu', 'anz', 'gntu-1gb-sgp1-01', 'rocks', 'ug', 'tr', 'gong', 'dz', 'ar', 'dsnet', 'pop', 'asia', 'kr', 'adsl', 'mu', 'mz', 'an', 'sn', 'li', 'mw', 'guru', 'ee', 'by', 'int', 'ao', 'center', 'mx', 'sk', 'ke', 'gy', 'dir', 'kg', 'sg', 've', 'vu', 'il', 'ovh', 'kh', 'com', 'localhost', 'kw', 'tg', 'nz', 'local', 'name', 'sv', 'crtnet', 'gn', '61-savecom', 'eu', 'tw', 'nc', 'koeln', 'as18190', 'ye', 'id', 'ps', 'hk', 'location', 'su', 'sh', 'ls', 'tn', 'us', 'om', 'any', 'milleniumtelecom', 'digital', 'md', 'zw', 'work', 'lv', 'io', 'la', 'servicos', '001', 'in', 'jp', 'lk', 'fo', 'bi', 'is', 'mobi', 'ac', 'london', 'lan', 'mailnet', 'ph', 'dm', 'gh', 'jo', 'mp', 'es', 'this', 'win', 'pg', 'email', 'ae', 'info', 'edu', 'ag', 'cnc', '210-twnap', 'bt', 'bz', 'jm', 'tv', 'ci', 'limited', 'mr', 'static', 'pe', 'ng', 'ltd', 'bitch', '4-x64', 'online', 'hu', 'gr', 'bomp', 'pf', 'gt', 'tech', 'as34268', 'my', 'tz', 'cat', 'cricket', 'ooe', 'ch', 'lu', 'st', 'pa', 'mobily', 'je', 'cw', 'lnoca', 'company', 'pvt', 'ml', 'ec', 'top', 'cd', 'ie', 'ly', 'pt', 'hr', 'mn', 'org', 'tc', 'np', 'sz', 'me', 'se', 'cm', 'na', 'review', 'global', 'ba', 'ct', 'host', 'univ', 'gg', 'gm', 'et', 'ro', 'bg', 'ni', 'mg', 'iq', 'eclair', 'sx', 'im', 'si', 'configured', 'ge', 'dk', 'mc', 'farm', 'fi', 'mh', 'az', 'network', 'ms', 'ua', 'tt', 'mv', 'zm', 'mo', 'dj', 'eg', 'fj', 'ck', 'cl', 'ga', 'new-york', 'ohio-state', 'lt', 'cn', 'as', 'fr', 'bb', 'pw', 'sr', 'no', 'sa', 'ky', 'am', 'pr', '0beta', 'msft', 'do', 'au', 'net', 'qa', 'pro', '01', 'bh', 'nl', 'th', 'bo', 'hn', 'coop', 'mt', 'co', 'cv', 'sm', 'ma', 'gov'}

# %%
def get_networdDomain_suffix(x):
    suffix = x.split('.')[-1]

    suffix = suffix.replace("\\032","")

    if re.search('[a-zA-Z]', x):
        return suffix
    else:
        return ""

train_df['networdDomain_suffix'] = train_df['geoNetwork.networkDomain'].apply(get_networdDomain_suffix)

train_df['networdDomain_suffix'].value_counts()

# %%
def get_networdDomain_prefix(x):
    prefix = x.split('.')[0]

    if re.search('[a-zA-Z]', x):
        return prefix
    else:
        return ""

train_df['networdDomain_prefix'] = train_df['geoNetwork.networkDomain'].apply(get_networdDomain_prefix)

print(train_df['networdDomain_prefix'].nunique())
train_df['networdDomain_prefix'].value_counts()
# Out:
# 26120
# unknown             391111
# comcast              28743
# rr                   14827
# verizon              13640
# ttnet                13236
# comcastbusiness       9985
# hinet                 7919
# virginm               6414
# 3bb                   6046
# prod-infinitum        5960
# cox                   5812
# sbcglobal             5388
# btcentralplus         5304
# att                   5243
# google                5035
# optonline             4972
# totbb                 4895
# vnpt                  4508
# asianet               4437
# pldt                  4009
# rima-tde              3963
# amazonaws             3769
# com                   3671
# t-ipconnect           3656
# telecomitalia         3583
# qwest                 3546
# airtelbroadband       3389
# virtua                3318
# bell                  2904
# ztomy                 2845
#                      ...
# lphs                     1
# peace                    1
# idiada                   1
# printtime                1
# siberianet               1
# westernu                 1
# mexagon                  1
# comediedebethune         1
# ti-films                 1
# geek-dns                 1
# gvm                      1
# us-telecoms              1
# bjitgroup                1
# bitcconnect              1
# sanitorsinc              1
# modepsa                  1
# tbilgi                   1
# rasa-internet            1
# onoffset                 1
# hisi                     1
# netrocinha               1
# vision                   1
# btwi-llc                 1
# berlikomm                1
# planningchambers         1
# poderjudicial            1
# joincolo                 1
# bakelsph                 1
# tech-trans               1
# ipex                     1
# Name: networdDomain_prefix, Length: 26120, dtype: int64

# %%
def merge_some_similar_networkDomain(x):
    x = x.replace("(not set)","unknown.unknown")
    
    return x


train_df['geoNetwork.networkDomain'] = train_df['geoNetwork.networkDomain'].apply(merge_some_similar_networkDomain)


print(train_df["geoNetwork.networkDomain"].value_counts(),'\n\n',test_df["geoNetwork.networkDomain"].value_counts())
# Out:
# unknown.unknown           390915
# comcast.net                28743
# rr.com                     14827
# verizon.net                13637
# ttnet.com.tr               13228
# comcastbusiness.net         9985
# hinet.net                   7919
# virginm.net                 6414
# 3bb.co.th                   6046
# prod-infinitum.com.mx       5960
# cox.net                     5812
# sbcglobal.net               5388
# btcentralplus.com           5304
# att.net                     5230
# google.com                  5035
# optonline.net               4972
# totbb.net                   4895
# vnpt.vn                     4508
# asianet.co.th               4374
# pldt.net                    4008
# rima-tde.net                3963
# amazonaws.com               3769
# t-ipconnect.de              3656
# telecomitalia.it            3571
# qwest.net                   3534
# airtelbroadband.in          3389
# virtua.com.br               3318
# bell.ca                     2904
# ztomy.com                   2845
# bhn.net                     2651
#                            ...
# asiatelnet.com                 1
# tviptel.net                    1
# ip-167-114-141.net             1
# bygmagruppen.dk                1
# komazawa-u.ac.jp               1
# didata.com                     1
# linkpath1.ru                   1
# whctcomm.net                   1
# totvs.com.br                   1
# porsche.co.at                  1
# edc.ro                         1
# wellington.com                 1
# americanlenders.com            1
# dilf.dk                        1
# madrid.es                      1
# cbplans.com                    1
# cookcountyil.gov               1
# ifc-system.com                 1
# firsthotelgrand.se             1
# paneveziospaustuve.lt          1
# lmg.net                        1
# gobiernodecanarias.org         1
# usu.ac.id                      1
# solen.com.tr                   1
# shelterpoint.com               1
# mvsu.edu                       1
# freekupon.net                  1
# mecklenburg.nc.us              1
# dev-globalrelay.net            1
# conel.ac.uk                    1
# Name: geoNetwork.networkDomain, Length: 28063, dtype: int64
#
#  (not set)                   254168
# unknown.unknown             123762
# comcast.net                  26743
# rr.com                       13888
# verizon.net                  12910
# hinet.net                     8014
# comcastbusiness.net           6841
# virginm.net                   6180
# sbcglobal.net                 5208
# google.com                    4962
# cox.net                       4910
# optonline.net                 4762
# rima-tde.net                  4115
# att.net                       4025
# prod-infinitum.com.mx         3965
# ttnet.com.tr                  3850
# btcentralplus.com             3848
# qwest.net                     3411
# vnpt.vn                       3154
# tedata.net                    3054
# bell.ca                       3052
# telecomitalia.it              2834
# bhn.net                       2712
# asianet.co.th                 2693
# spcsdns.net                   2612
# airtelbroadband.in            2602
# shawcable.net                 2482
# t-ipconnect.de                2461
# actcorp.in                    2270
# sfr.net                       2104
#                              ...
# conecttiva.com.br                1
# cundall.com                      1
# mksat.net                        1
# userdns.com                      1
# rhythmone.com                    1
# margonet.pl                      1
# relant.ru                        1
# arthrosis.gr                     1
# areyouonline.net                 1
# morris.com                       1
# icsolutions.info                 1
# sonycentre.ca                    1
# chelmer.co.nz                    1
# databaselabs.io                  1
# eunet.fi                         1
# truongthanh.com                  1
# stream.uz                        1
# dfinet.net                       1
# egrivar.hu                       1
# artlite.cz                       1
# claroconnect.co.za               1
# ak-pkk.cz                        1
# santaclarapueblo.org             1
# onealinc.com                     1
# valeoconstruction.com.au         1
# kt-net.net                       1
# kw1c.nl                          1
# safarelec.ma                     1
# fsmtc.fm                         1
# pharmaidea.com                   1
# Name: geoNetwork.networkDomain, Length: 25750, dtype: int64

# %%
train_df["gclId_prefix"] = train_df["trafficSource.adwordsClickInfo.gclId"].apply(lambda x: str(x).split('_')[0])

# %%
def merge_campaign(x):
    if str(x).find('AW')>=0:
        return 1
    elif str(x).find('Data Share')>=0:
        return 2
    else:
        return 3
    

train_df["campaign_merge"] = train_df["trafficSource.campaign"].apply(merge_campaign)

# %%
def keyword_merge(x):
    if str(x).lower().find("store")>=0 or str(x).lower().find("shop")>=0:
        return "google store"
    elif str(x).lower().find('merchandise')>=0 or str(x).lower().find('merch')>=0:
        return "merchandise"
    elif str(x).lower().find('tube')>=0:
        return "youtube"
    elif str(x).lower().find('shirt')>=0:
        return "shirt"
    elif str(x).lower().find('targeting')>=0:
        return "targeting"
    else:
        if len(str(x).lower().split(' '))>1:
            x = str(x).lower().split(' ')[1]
        else:
            x = str(x).lower()
               
        x = x.replace('+','')
        return x


train_df["keyword_merge"] = train_df["trafficSource.keyword"].apply(keyword_merge)

# %%
def referralPath_language(x):
    if str(x).find('/yt/about')>=0:
        x = str(x)[10:]
        x = x.split('/')[0]
        return x
    
    return 'unknown'
        
train_df["referralPath_language"] = train_df["trafficSource.referralPath"].apply(referralPath_language)

# %%
def referralPath_prefix(x):
    array = str(x).split('/')
    if len(array)>1:
        return array[1]
    
    return x
        
train_df["referralPath_prefix"] = train_df["trafficSource.referralPath"].apply(referralPath_prefix)

# %%
def source_suffix(x):
    if str(x).find('.com')>=0:
        return 'com'
    elif str(x).find('.')>=0:
        return str(x).split('.')[-1]
    
    return x
        
train_df["source_suffix"] = train_df["trafficSource.source"].apply(source_suffix)

# %%
def source_prefix(x):
    if str(x).find('.')>=0:
        return str(x).split('.')[0]
    
    return x
        
train_df["source_prefix"] = train_df["trafficSource.source"].apply(source_prefix)

# %%
train_df["source_prefix"].value_counts()
# Out:
# google                        406384
# youtube                       212602
# (direct)                      143028
# mall                           66416
# Partners                       16411
# analytics                      16186
# dfa                             5686
# m                               3775
# baidu                           3361
# sites                           2983
# facebook                        2296
# siliconvalley                   2097
# reddit                          2022
# qiita                           1813
# quora                           1546
# bing                            1534
# t                               1529
# yahoo                           1481
# mail                            1463
# gdeals                          1063
# groups                          1025
# l                                845
# blog                             742
# plus                             677
# dealspotr                        528
# moma                             419
# docs                             388
# productforums                    364
# sashihara                        277
# ask                              270
#                                ...
# voice                              1
# meetup                             1
# brewmaster                         1
# login                              1
# de                                 1
# gsuite                             1
# digg                               1
# biztools                           1
# gdeals-stg                         1
# adwords-displayads-nightly         1
# invincible                         1
# tumblr                             1
# goto                               1
# ps-dm                              1
# x20web                             1
# cc                                 1
# prod                               1
# adwords-next-nightly               1
# collaborate                        1
# newsstand                          1
# plusapp-autopush                   1
# takeout                            1
# earth                              1
# intranet                           1
# mobile                             1
# computerworld                      1
# yt-go-12345                        1
# hosted                             1
# cases2                             1
# benkraft                           1
# Name: source_prefix, Length: 230, dtype: int64

# %%
cate_features = []
numeric_features = []

train['fullVisitorId'] = train['fullVisitorId'].astype(str)
test['fullVisitorId'] = test['fullVisitorId'].astype(str)

train['channelGrouping'] = label.fit_transform(train['channelGrouping'])
test['channelGrouping'] = label.fit_transform(test['channelGrouping'])

cate_features.append('channelGrouping')

def label_transform(df, col_list):
    for col in col_list:
        df[col] = label.fit_transform(df[col])

    return df

####################################
date_features = ['date','year','month','day','week','weekofyear','dayofweek','quarter','month_start','month_end']

def process_date(df):
    df['date'] = pd.to_datetime(df['date'], format='%Y%m%d',errors='ignore')
    df['year'] = df['date'].dt.year
    df['month'] = df['date'].dt.month
    df['day'] = df['date'].dt.day

    df['week'] = df['date'].dt.week
    df['weekofyear'] = df['date'].dt.weekofyear
    df['dayofweek'] = df['date'].dt.dayofweek
    df['quarter'] = df['date'].dt.quarter
    df['month_start'] = df['date'].dt.is_month_start
    df['month_end'] = df['date'].dt.is_month_end

    df = label_transform(df, date_features)
    
    return df

train = process_date(train)
test = process_date(test)
cate_features += date_features
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-a4f143d02ddb> in <module>()
#      37     return df
#      38
# ---> 39 train = process_date(train)
#      40 test = process_date(test)
#      41 cate_features += date_features
#
# <ipython-input-5-a4f143d02ddb> in process_date(df)
#      22 def process_date(df):
#      23     df['date'] = pd.to_datetime(df['date'], format='%Y%m%d',errors='ignore')
# ---> 24     df['year'] = df['date'].dt.year
#      25     df['month'] = df['date'].dt.month
#      26     df['day'] = df['date'].dt.day
#
# ~/ai/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370         if (name in self._internal_names_set or name in self._metadata or
#    4371                 name in self._accessors):
# -> 4372             return object.__getattribute__(self, name)
#    4373         else:
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/ai/lib/python3.6/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/ai/lib/python3.6/site-packages/pandas/core/indexes/accessors.py in __new__(cls, data)
#     323             pass  # we raise an attribute error anyway
#     324
# --> 325         raise AttributeError("Can only use .dt accessor with datetimelike "
#     326                              "values")
#
# AttributeError: Can only use .dt accessor with datetimelike values

# %%
################device####################
device_features = ['browser','operatingSystem','isMobile','deviceCategory']

def process_device(df):
    df['browser'] = df['device'].apply(lambda x: json.loads(x)['browser'])
    df['operatingSystem'] = df['device'].apply(lambda x: json.loads(x)['operatingSystem'])
    df['isMobile'] = df['device'].apply(lambda x: json.loads(x)['isMobile'])
    df['deviceCategory'] = df['device'].apply(lambda x: json.loads(x)['deviceCategory'])

    df = label_transform(df, device_features)

    return df

train = process_device(train)
test = process_device(test)
cate_features += device_features



###############geoNetwork#####################
geo_features = ['continent','subContinent','country','region','metro','city','networkDomain']

def process_geo(df):
    df['continent'] = df['geoNetwork'].apply(lambda x: json.loads(x)['continent'])
    df['subContinent'] = df['geoNetwork'].apply(lambda x: json.loads(x)['subContinent'])
    df['country'] = df['geoNetwork'].apply(lambda x: json.loads(x)['country'])
    df['region'] = df['geoNetwork'].apply(lambda x: json.loads(x)['region'])
    df['metro'] = df['geoNetwork'].apply(lambda x: json.loads(x)['metro'])
    df['city'] = df['geoNetwork'].apply(lambda x: json.loads(x)['city'])
    df['networkDomain'] = df['geoNetwork'].apply(lambda x: json.loads(x)['networkDomain'])

    df = label_transform(df, geo_features)

    return df

train = process_geo(train)
test = process_geo(test)
cate_features += geo_features



################totals####################
view_features = ['hits','pageviews','newVisits','bounces','visitNumber']

def process_totals(df):
    df['hits'] = df['totals'].apply(lambda x: json.loads(x)['hits']).astype(int)
    df['pageviews'] = df['totals'].apply(lambda x: json.loads(x)['pageviews'] if x.find('pageviews')>=0 else 0).astype(int)
    df['bounces'] = df['totals'].apply(lambda x: json.loads(x)['bounces'] if x.find('bounces')>=0 else 0).astype(int)
    df['newVisits'] = df['totals'].apply(lambda x: json.loads(x)['newVisits'] if x.find('newVisits')>=0 else 0).astype(int)
    df['transactionRevenue'] = df['totals'].apply(lambda x: json.loads(x)['transactionRevenue'] if x.find('transactionRevenue')>=0 else 0).astype(int)

    return df

train = process_totals(train)
test = process_totals(test)
numeric_features += view_features



################totals####################
last_time_features = ['last_seconds','last_minutes']

def process_last_time(df):
    df['last_seconds'] = df['visitStartTime']-df['visitId']
    df['last_minutes'] = (df['visitStartTime']-df['visitId'])/60
    df['last_minutes'] = df['last_minutes'].astype(np.int64)

    return df

train = process_last_time(train)
test = process_last_time(test)
numeric_features += last_time_features


################Multip transaction####################
def process_transaction_count(df):
    transaction_df = train[['fullVisitorId','transactionRevenue']].groupby('fullVisitorId')
        
    transac_count_df = transaction_df.count()
    transac_count_df['fullVisitorId'] = transac_count_df.index
    transac_count_df.rename(columns={
        'transactionRevenue':'transaction_count'
    }, inplace=True)
    transac_count_df['transaction_count'] = transac_count_df['transaction_count'].astype(int)

    df = pd.merge(df, transac_count_df, on='fullVisitorId')

    return df

train = process_transaction_count(train)
test = process_transaction_count(test)
numeric_features.append('transaction_count')

def process_buy_times(df):
    transaction_df = df[['fullVisitorId','transactionRevenue']].groupby('fullVisitorId')

    def count_buy_times(x):
        buy_times = sum(x['transactionRevenue']>0)

        return buy_times

    buy_times_group = transaction_df.apply(count_buy_times)
    buy_times_df = pd.DataFrame({
        'fullVisitorId':buy_times_group.index,
        'buy_times':buy_times_group.values
    })

    df = pd.merge(df, buy_times_df, on='fullVisitorId')

    return df

train = process_buy_times(train)
test = process_buy_times(test)
numeric_features.append('buy_times')


def parse_adwordsClickInfo_field(x, field):
    jo = json.loads(x)
    
    if x.find('adwordsClickInfo')>=0:
        adwordsClickInfo = jo['adwordsClickInfo']
        
        if str(adwordsClickInfo).find(field)>=0:
            return adwordsClickInfo[field]

    return 0

def parse_adwordsClickInfo_page(x):
    return parse_adwordsClickInfo_field(x, 'page')

def parse_adwordsClickInfo_slot(x):
    return parse_adwordsClickInfo_field(x, 'slot')

def parse_adwordsClickInfo_gclId(x):
    return parse_adwordsClickInfo_field(x, 'gclId')

def parse_adwordsClickInfo_adNetworkType(x):
    return parse_adwordsClickInfo_field(x, 'adNetworkType')

def parse_adwordsClickInfo_isVideoAd(x):
    return parse_adwordsClickInfo_field(x, 'isVideoAd')

traffic_features = ['campaign','source','medium','keyword','adwordsClickInfo_gclId_prefix','adwordsClickInfo_slot',
                    'adwordsClickInfo_gclId','adwordsClickInfo_adNetworkType']

def process_traffic(df):
    df['campaign'] = df['trafficSource'].apply(lambda x: json.loads(x)['campaign']).astype(str)
    # need to merge nearly same record
    df['source'] = df['trafficSource'].apply(lambda x: json.loads(x)['source']).astype(str)
    df['medium'] = df['trafficSource'].apply(lambda x: json.loads(x)['medium']).astype(str)
    # need to merge some keywords
    df['keyword'] = df['trafficSource'].apply(lambda x: json.loads(x)['keyword'] if x.find('keyword')>=0 else 0).astype(str)

    df['adwordsClickInfo_page'] = df['trafficSource'].apply(parse_adwordsClickInfo_page).astype(int)
    df['adwordsClickInfo_slot'] = df['trafficSource'].apply(parse_adwordsClickInfo_slot).astype(str)
    df['adwordsClickInfo_gclId'] = df['trafficSource'].apply(parse_adwordsClickInfo_gclId).astype(str)
    df['adwordsClickInfo_gclId_prefix'] = df['adwordsClickInfo_gclId'].apply(lambda x: x.split('_')[0] if type(x)!=int and x.find('_')>=0 else 0).astype(str)
    df['adwordsClickInfo_adNetworkType'] = df['trafficSource'].apply(parse_adwordsClickInfo_adNetworkType).astype(str)

    df = label_transform(df, traffic_features)
    
    return df

train = process_traffic(train)
test = process_traffic(test)

cate_features += traffic_features
numeric_features.append('adwordsClickInfo_page')



###################################################### 
target = 'revenue'

def process_revenue(df):
    revenue_df = df[['fullVisitorId','transactionRevenue']].groupby('fullVisitorId').agg('sum')
    revenue_df['fullVisitorId'] = revenue_df.index
    revenue_df[target] = revenue_df['transactionRevenue'].apply(lambda x: np.log(x+1))
    
    revenue_df.drop('transactionRevenue', axis=1, inplace=True)
    
    df = pd.merge(df, revenue_df, on='fullVisitorId')

    return df


train = process_revenue(train)
test = process_revenue(test)

removed_columns = ['device','geoNetwork','socialEngagementType','totals','trafficSource']
train.drop(removed_columns, axis=1, inplace=True)
train.columns


print(len(train['fullVisitorId'].unique()))

# %%
d_rows = train[train['fullVisitorId'].duplicated(keep=False)]


def merge_data(x):
    mode_array = x.mode().values
    
    return mode_array[0]

duplicated_ids = d_rows['fullVisitorId'].unique()
print('duplicated id size',len(duplicated_ids))
train_copy = train.copy()

duplicated_df = pd.DataFrame({
    'fullVisitorId':duplicated_ids
})

temp = train_copy.apply(lambda x: print(x.name), axis=0)

temp.head()

# for id in unique_ids:
#     temp_mode = train[train['fullVisitorId'] == id].apply(merge_data, axis=0)
    
#     train = train.append(temp_mode,ignore_index=True)

    
# train.drop(d_rows.index, inplace=True)

# print('train.shape',train.shape)
# print('d_rows.shape',d_rows.shape)

# print(len(d_rows['fullVisitorId'].unique()))
# Out:
# duplicated id size 609
# channelGrouping
# date
# fullVisitorId
# sessionId
# visitId
# visitNumber
# visitStartTime
# year
# month
# day
# week
# weekofyear
# dayofweek
# quarter
# month_start
# month_end
# browser
# operatingSystem
# isMobile
# deviceCategory
# continent
# subContinent
# country
# region
# metro
# city
# networkDomain
# hits
# pageviews
# bounces
# newVisits
# transactionRevenue
# last_seconds
# last_minutes
# transaction_count
# buy_times
# campaign
# source
# medium
# keyword
# adwordsClickInfo_page
# adwordsClickInfo_slot
# adwordsClickInfo_gclId
# adwordsClickInfo_gclId_prefix
# adwordsClickInfo_adNetworkType
# revenue
# channelGrouping    None
# date               None
# fullVisitorId      None
# sessionId          None
# visitId            None
# dtype: object

# %%
train = pd.read_csv(dir + train_file, low_memory=False)
test = pd.read_csv(dir + test_file, low_memory=False)


def process_totals(df):
    df['hits'] = df['totals'].apply(lambda x: json.loads(x)['hits']).astype(int)
    df['pageviews'] = df['totals'].apply(lambda x: json.loads(x)['pageviews'] if x.find('pageviews')>=0 else 0).astype(int)
    df['bounces'] = df['totals'].apply(lambda x: json.loads(x)['bounces'] if x.find('bounces')>=0 else 0).astype(int)
    df['newVisits'] = df['totals'].apply(lambda x: json.loads(x)['newVisits'] if x.find('newVisits')>=0 else 0).astype(int)
    df['transactionRevenue'] = df['totals'].apply(lambda x: json.loads(x)['transactionRevenue'] if x.find('transactionRevenue')>=0 else 0).astype(int)

    return df

train = process_totals(train)


target = 'revenue'

def process_revenue(df):
    revenue_df = df[['fullVisitorId','transactionRevenue']].groupby('fullVisitorId').agg('sum')
    revenue_df['fullVisitorId'] = revenue_df.index
    revenue_df[target] = revenue_df['transactionRevenue'].apply(lambda x: np.log(x+1))
    
    revenue_df.drop('transactionRevenue', axis=1, inplace=True)
    
    df = pd.merge(df, revenue_df, on='fullVisitorId')

    return df


train = process_revenue(train)

transactionRevenue = train[target].unique()

print(transactionRevenue)
# Out:
# [ 0.         17.97189053 17.08317659 17.44940573 19.54128281 18.03545936
#  17.37314175 20.16840125 15.94135859 19.79624272 16.99689222 17.38447974
#  18.21611359 20.11871544 18.58058627 17.59308749 19.64142217 17.35589003
#  17.38193988 19.64159916 17.33211782 20.26992265 18.45256694 19.53736214
#  15.45450747 18.32472036 16.17542081 17.06122308 19.28268423 16.94969962
#  20.20223835 17.98527177 17.61749548 17.2296242  16.21249642 17.03398634
#  16.6469577  16.01051055 17.2404245  19.27917286 16.29707839 17.86851217
#  19.00378982 18.20699236 19.37376618 18.48139949 17.46226511 17.7963131
#  17.2806213  18.3878476  19.39444762 18.47061312 20.79744524 15.75999126
#  19.63056604 19.51515114 17.117992   17.3412827  17.72753358 18.37954621
#  18.50823365 19.52045902 17.66926868 16.63629409 18.5474896  15.82774348
#  16.40252251 18.1974122  18.12751702 17.86868586 16.42484486 16.11609375
#  17.26518062 16.86098497 18.52648117 18.97387597 16.64813555 17.45204356
#  19.31284271 17.57601278 16.68284117 16.81074276 15.89370144 14.5036457
#  16.53614794 17.2790566  18.75464986]
# /Users/xinwang/ai/lib/python3.6/site-packages/ipykernel_launcher.py:31: FutureWarning: 'fullVisitorId' is both an index level and a column label.
# Defaulting to column, but this will raise an ambiguity error in a future version

# %%
print('transactionRevenue.mean',transactionRevenue.mean())
# Out:
# transactionRevenue.mean 17.629718972025067

# %%
# groupby works well 
from tqdm import tqdm

print('unique fullVisitorId size ',len(train['fullVisitorId'].unique()))

d_rows = train[train['fullVisitorId'].duplicated(keep=False)]
revisted_df = train.loc[d_rows.index]


def merge_func(df):
    def merge_one_column(x):
        new_merged_value=x.mode().values[0]
        return new_merged_value
    
    temp = df.apply(merge_one_column)
    return temp

tqdm.pandas()

merged_df = revisted_df.loc[0:100].groupby('fullVisitorId').progress_apply(merge_func)
merged_df['fullVisitorId'] = merged_df.index

print('*'*80)
print(merged_df.shape)
merged_df.head(20)

# %%
# Another solution of groupby mode 
# works well
from tqdm import tqdm

def merge_func(group):
    new_value = group.mode().values[0]
    print('',group,group.name,group.values,new_value)
    print('-'*50)
    
    return new_value

tqdm.pandas()

merged_df = revisted_df.loc[0:10].groupby('fullVisitorId').agg(merge_func)
merged_df['fullVisitorId'] = merged_df.index

print(merged_df.shape)

# %%
from joblib import Parallel, delayed
from multiprocessing import Pool, cpu_count
import tqdm
import time


def applyParallel(dfGrouped, func):
    with Pool(cpu_count()) as p:
        ret_list = list(tqdm.tqdm(
            p.imap(func, [group for name, group in dfGrouped]), 
            total=10))

    df = pd.concat(ret_list, axis=1)
    df = df.T
    return df


def merge_group_func(df):
    def merge_one_column(x):
        new_merged_value=x.mode().values[0]
        return new_merged_value

    temp = df.apply(merge_one_column)

    return temp

def merge_duplicated_into_new_row(df):
    print()
    print('unique fullVisitorId size ',df.shape, len(df['fullVisitorId'].unique()))

    d_rows = df[df['fullVisitorId'].duplicated(keep=False)]
    revisted_df = df.loc[d_rows.index]
    print('revisted_df.shape',revisted_df.shape)

    new_merged_df = applyParallel(revisted_df.groupby('fullVisitorId'),merge_group_func)
    print('new_merged_df.shape',new_merged_df.shape)

    df.drop(d_rows.index, inplace=True)
    
    df = pd.concat([df,new_merged_df], axis=0)
    del d_rows
    del new_merged_df
    
    print('df.shape',df.shape)

    return df
    

train = merge_duplicated_into_new_row(train)
print('merge_duplicated_into_new_row done')

print()
print('train.shape', train.shape)
train.head()
# Out:
# unique fullVisitorId size  (9999, 12) 9250
# revisted_df.shape (1358, 12)
#   0%|          | 0/10 [00:00<?, ?it/s]
# 104it [00:00, 980.97it/s]
# 202it [00:00, 993.60it/s]
# 304it [00:00, 991.00it/s]
# 401it [00:00, 985.50it/s]
# 508it [00:00, 993.78it/s]
# 609it [00:00, 1013.71it/s]
# new_merged_df.shape (609, 12)
# df.shape (9250, 12)
# merge_duplicated_into_new_row done
#
# train.shape (9250, 12)
#   channelGrouping      date  \
# 0  Organic Search  20160902
# 1  Organic Search  20160902
# 2  Organic Search  20160902
# 3  Organic Search  20160902
# 4  Organic Search  20160902
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                device  \
# 0     {"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Windows", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# 1  {"browser": "Firefox", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Macintosh", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# 2     {"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Windows", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# 3   {"browser": "UC Browser", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Linux", "operatingSystemVersion": "not available in demo dataset", "isMobile": false, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "desktop"}
# 4       {"browser": "Chrome", "browserVersion": "not available in demo dataset", "browserSize": "not available in demo dataset", "operatingSystem": "Android", "operatingSystemVersion": "not available in demo dataset", "isMobile": true, "mobileDeviceBranding": "not available in demo dataset", "mobileDeviceModel": "not available in demo dataset", "mobileInputSelector": "not available in demo dataset", "mobileDeviceInfo": "not available in demo dataset", "mobileDeviceMarketingName": "not available in demo dataset", "flashVersion": "not available in demo dataset", "language": "not available in demo dataset", "screenColors": "not available in demo dataset", "screenResolution": "not available in demo dataset", "deviceCategory": "mobile"}
#
#          fullVisitorId  \
# 0  1131660440785968503
# 1   377306020877927890
# 2  3895546263509774583
# 3  4763447161404445595
# 4    27294437909732085
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                             geoNetwork  \
# 0                                                                                      {"continent": "Asia", "subContinent": "Western Asia", "country": "Turkey", "region": "Izmir", "metro": "(not set)", "city": "Izmir", "cityId": "not available in demo dataset", "networkDomain": "ttnet.com.tr", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# 1              {"continent": "Oceania", "subContinent": "Australasia", "country": "Australia", "region": "not available in demo dataset", "metro": "not available in demo dataset", "city": "not available in demo dataset", "cityId": "not available in demo dataset", "networkDomain": "dodo.net.au", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# 2                                                                {"continent": "Europe", "subContinent": "Southern Europe", "country": "Spain", "region": "Community of Madrid", "metro": "(not set)", "city": "Madrid", "cityId": "not available in demo dataset", "networkDomain": "unknown.unknown", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# 3          {"continent": "Asia", "subContinent": "Southeast Asia", "country": "Indonesia", "region": "not available in demo dataset", "metro": "not available in demo dataset", "city": "not available in demo dataset", "cityId": "not available in demo dataset", "networkDomain": "unknown.unknown", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
# 4  {"continent": "Europe", "subContinent": "Northern Europe", "country": "United Kingdom", "region": "not available in demo dataset", "metro": "not available in demo dataset", "city": "not available in demo dataset", "cityId": "not available in demo dataset", "networkDomain": "unknown.unknown", "latitude": "not available in demo dataset", "longitude": "not available in demo dataset", "networkLocation": "not available in demo dataset"}
#
#                         sessionId  socialEngagementType  \
# 0  1131660440785968503_1472830385  Not Socially Engaged
# 1   377306020877927890_1472880147  Not Socially Engaged
# 2  3895546263509774583_1472865386  Not Socially Engaged
# 3  4763447161404445595_1472881213  Not Socially Engaged
# 4    27294437909732085_1472822600  Not Socially Engaged
#
#                                                                              totals  \
# 0  {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}
# 1  {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}
# 2  {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}
# 3  {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1", "newVisits": "1"}
# 4                    {"visits": "1", "hits": "1", "pageviews": "1", "bounces": "1"}
#
#                                                                                                                                                                                         trafficSource  \
# 0                        {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "(not provided)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}
# 1                        {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "(not provided)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}
# 2                        {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "(not provided)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}
# 3                       {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "google + online", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}}
# 4  {"campaign": "(not set)", "source": "google", "medium": "organic", "keyword": "(not provided)", "adwordsClickInfo": {"criteriaParameters": "not available in demo dataset"}, "isTrueDirect": true}
#
#       visitId visitNumber visitStartTime
# 0  1472830385           1     1472830385
# 1  1472880147           1     1472880147
# 2  1472865386           1     1472865386
# 3  1472881213           1     1472881213
# 4  1472822600           2     1472822600

# %%
transaction_value_counts_df = pd.DataFrame({
    'count':train['transaction_count'].value_counts().values,
    'value':train['transaction_count'].value_counts().index,
    'percent': 100.0*(train['transaction_count'].value_counts().values/train['transaction_count'].count())
})

transaction_value_counts_df.head(20)
